# %%
from datetime import datetime
import pandas as pd
import numpy as np
from pathlib import Path

# %%
path = "tempdir/benchmark"  # or unix / linux / mac path

# Get the files from the path provided in the OP
files = Path(path).glob('*.csv')

columns_to_merge = {
    'Date' : 'DATE',
    'Tm End Date' : 'DATE',
    'NHSE region code': 'NHSE_REGION_CODE',
    'NHSE region name': 'NHSE_REGION_NAME',
    'Org code': 'ORG_CODE',
    'Org name': 'ORG_NAME',
    'Org Code': 'ORG_CODE',
    'Org Name': 'ORG_NAME',
    'Org Type': 'ORG_TYPE',
    'FTE days lost': 'FTE_DAYS_LOST',
    'FTE Days Sick' : 'FTE_DAYS_LOST',
    'FTE days available': 'FTE_DAYS_AVAILABLE',
    'FTE Days Available' : 'FTE_DAYS_AVAILABLE',
    'Sickness absence rate (%)': 'SICKNESS_ABSENCE_RATE_PERCENT',
    'Staff group': 'STAFF_GROUP',
    'Cluster group': 'CLUSTER_GROUP',
    'Benchmark group': 'BENCHMARK_GROUP',
}

# %%
list(columns_to_merge.values())
# Out:
# ['DATE',
#  'DATE',
#  'NHSE_REGION_CODE',
#  'NHSE_REGION_NAME',
#  'ORG_CODE',
#  'ORG_NAME',
#  'ORG_CODE',
#  'ORG_NAME',
#  'ORG_TYPE',
#  'FTE_DAYS_LOST',
#  'FTE_DAYS_LOST',
#  'FTE_DAYS_AVAILABLE',
#  'FTE_DAYS_AVAILABLE',
#  'SICKNESS_ABSENCE_RATE_PERCENT',
#  'STAFF_GROUP',
#  'CLUSTER_GROUP',
#  'BENCHMARK_GROUP']

# %%
dfs = list()
df = None

for f in files:
    #print(f)
    data = pd.read_csv(f)
    # .stem is method for pathlib objects to get the filename w/o the extension
    data['file_date'] = str(f)[18:28] # Varies depending on name
    data.columns = [columns_to_merge.get(k,k) for k in data.columns]
    list(data)
    dfs.append(data)

df = pd.concat(dfs, ignore_index=True)
# Out:
# C:\Users\MarieRogers\AppData\Local\Temp\ipykernel_15688\3446564026.py:6: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(f)

# %%
list(df)
# Out:
# ['Month',
#  'ORG_CODE',
#  'ORG_NAME',
#  'HEE region code',
#  'HEE region name',
#  'CLUSTER_GROUP',
#  'BENCHMARK_GROUP',
#  'NHSE_REGION_CODE',
#  'NHSE_REGION_NAME',
#  'STAFF_GROUP',
#  'FTE_DAYS_LOST',
#  'FTE_DAYS_AVAILABLE',
#  'SICKNESS_ABSENCE_RATE_PERCENT',
#  'file_date',
#  'DATE',
#  'ICS_CODE',
#  'ICS_NAME']

# %%
df1 = df[["file_date", "DATE", "ORG_CODE", "ORG_NAME", "NHSE_REGION_CODE", "NHSE_REGION_NAME", "CLUSTER_GROUP", "BENCHMARK_GROUP", "STAFF_GROUP", "FTE_DAYS_LOST", "FTE_DAYS_AVAILABLE"]]

# %%
df1.tail()
# Out:
#           file_date        DATE ORG_CODE  \
# 4456822  2023-06-01  30/06/2023      X80
# 4456823  2023-06-01  30/06/2023      X80
# 4456824  2023-06-01  30/06/2023      X80
# 4456825  2023-06-01  30/06/2023      X80
# 4456826  2023-06-01  30/06/2023      X80
#
#                                                   ORG_NAME NHSE_REGION_CODE  \
# 4456822  National Institute for Health and Care Excellence              QZZ
# 4456823  National Institute for Health and Care Excellence              QZZ
# 4456824  National Institute for Health and Care Excellence              QZZ
# 4456825  National Institute for Health and Care Excellence              QZZ
# 4456826  National Institute for Health and Care Excellence              QZZ
#
#                                           NHSE_REGION_NAME CLUSTER_GROUP  \
# 4456822  Special Health Authorities and other statutory...        Others
# 4456823  Special Health Authorities and other statutory...        Others
# 4456824  Special Health Authorities and other statutory...        Others
# 4456825  Special Health Authorities and other statutory...        Others
# 4456826  Special Health Authorities and other statutory...        Others
#
#         BENCHMARK_GROUP                                       STAFF_GROUP  \
# 4456822          Others                                      HCHS Doctors
# 4456823          Others                                 Central functions
# 4456824          Others                                          Managers
# 4456825          Others                                   Senior managers
# 4456826          Others  Other staff or those with unknown classification
#
#          FTE_DAYS_LOST  FTE_DAYS_AVAILABLE
# 4456822            NaN                 NaN
# 4456823      326.84667         13834.71392
# 4456824      133.13333         10320.09980
# 4456825            NaN                 NaN
# 4456826            NaN                 NaN

# %%
# set date columns to date types
df1['DATE'] = pd.to_datetime(df1['DATE'], format='mixed')
df1['file_date'] = pd.to_datetime(df['file_date'], yearfirst = True)
# Out:
# C:\Users\MarieRogers\AppData\Local\Temp\ipykernel_15688\3414648935.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['DATE'] = pd.to_datetime(df1['DATE'], format='mixed')

# %%
df1.sort_values(by='file_date').tail()
# Out:
#          file_date       DATE ORG_CODE  \
# 4454719 2023-06-01 2023-06-30      RDE
# 4454720 2023-06-01 2023-06-30      RDE
# 4454721 2023-06-01 2023-06-30      RDE
# 4454723 2023-06-01 2023-06-30      RDE
# 4456826 2023-06-01 2023-06-30      X80
#
#                                                   ORG_NAME NHSE_REGION_CODE  \
# 4454719  East Suffolk and North Essex NHS Foundation Trust              Y61
# 4454720  East Suffolk and North Essex NHS Foundation Trust              Y61
# 4454721  East Suffolk and North Essex NHS Foundation Trust              Y61
# 4454723  East Suffolk and North Essex NHS Foundation Trust              Y61
# 4456826  National Institute for Health and Care Excellence              QZZ
#
#                                           NHSE_REGION_NAME CLUSTER_GROUP  \
# 4454719                                    East of England         Acute
# 4454720                                    East of England         Acute
# 4454721                                    East of England         Acute
# 4454723                                    East of England         Acute
# 4456826  Special Health Authorities and other statutory...        Others
#
#         BENCHMARK_GROUP                                       STAFF_GROUP  \
# 4454719   Acute - Large                                   Ambulance staff
# 4454720   Acute - Large                                 Central functions
# 4454721   Acute - Large                         Hotel, property & estates
# 4454723   Acute - Large                                          Midwives
# 4456826          Others  Other staff or those with unknown classification
#
#          FTE_DAYS_LOST  FTE_DAYS_AVAILABLE
# 4454719        0.53333           337.00020
# 4454720      594.77955         23631.70701
# 4454721      810.75310         15810.13360
# 4454723      464.96648          8175.91670
# 4456826            NaN                 NaN

# %%
replace_dict_region = {'South East of England':'South East',
                'South West of England':'South West'}
replace_dict_staff = {'All staff':'All staff groups',
                'HCHS Doctors':'HCHS doctors (exc. junior Drs)',
                'HCHS doctors':'HCHS doctors (exc. junior Drs)'}

df1['NHSE_REGION_NAME'] = df1['NHSE_REGION_NAME'].replace(replace_dict_region)
df1['STAFF_GROUP'] = df1['STAFF_GROUP'].replace(replace_dict_staff)

df1 = df1.drop_duplicates()
# Out:
# C:\Users\MarieRogers\AppData\Local\Temp\ipykernel_15688\3521529705.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['NHSE_REGION_NAME'] = df1['NHSE_REGION_NAME'].replace(replace_dict_region)
# C:\Users\MarieRogers\AppData\Local\Temp\ipykernel_15688\3521529705.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['STAFF_GROUP'] = df1['STAFF_GROUP'].replace(replace_dict_staff)

# %%
df1 = df1.sort_values(by='file_date')

df1.tail()
# Out:
#          file_date       DATE ORG_CODE  \
# 4454719 2023-06-01 2023-06-30      RDE
# 4454720 2023-06-01 2023-06-30      RDE
# 4454721 2023-06-01 2023-06-30      RDE
# 4454723 2023-06-01 2023-06-30      RDE
# 4456826 2023-06-01 2023-06-30      X80
#
#                                                   ORG_NAME NHSE_REGION_CODE  \
# 4454719  East Suffolk and North Essex NHS Foundation Trust              Y61
# 4454720  East Suffolk and North Essex NHS Foundation Trust              Y61
# 4454721  East Suffolk and North Essex NHS Foundation Trust              Y61
# 4454723  East Suffolk and North Essex NHS Foundation Trust              Y61
# 4456826  National Institute for Health and Care Excellence              QZZ
#
#                                           NHSE_REGION_NAME CLUSTER_GROUP  \
# 4454719                                    East of England         Acute
# 4454720                                    East of England         Acute
# 4454721                                    East of England         Acute
# 4454723                                    East of England         Acute
# 4456826  Special Health Authorities and other statutory...        Others
#
#         BENCHMARK_GROUP                                       STAFF_GROUP  \
# 4454719   Acute - Large                                   Ambulance staff
# 4454720   Acute - Large                                 Central functions
# 4454721   Acute - Large                         Hotel, property & estates
# 4454723   Acute - Large                                          Midwives
# 4456826          Others  Other staff or those with unknown classification
#
#          FTE_DAYS_LOST  FTE_DAYS_AVAILABLE
# 4454719        0.53333           337.00020
# 4454720      594.77955         23631.70701
# 4454721      810.75310         15810.13360
# 4454723      464.96648          8175.91670
# 4456826            NaN                 NaN

# %%
df2 = df1.sort_values(by='file_date', ascending = False).groupby(['DATE', 'ORG_NAME', 'STAFF_GROUP']).first().reset_index()

# %%
#df2[(df2['ORG_NAME'] == 'Liverpool University Hospitals NHS Foundation Trust') & (df2['STAFF_GROUP']=="All staff groups")].sort_values(by='DATE', ascending = False)

# %%
df2 = df2.sort_values(by=['NHSE_REGION_CODE', 'ORG_NAME', 'CLUSTER_GROUP','DATE'], ascending = False)

# %%
df2.head()
# Out:
#              DATE                               ORG_NAME  \
# 242973 2023-06-30  Yorkshire Ambulance Service NHS Trust
# 242974 2023-06-30  Yorkshire Ambulance Service NHS Trust
# 242975 2023-06-30  Yorkshire Ambulance Service NHS Trust
# 242976 2023-06-30  Yorkshire Ambulance Service NHS Trust
# 242977 2023-06-30  Yorkshire Ambulance Service NHS Trust
#
#                            STAFF_GROUP  file_date ORG_CODE NHSE_REGION_CODE  \
# 242973                All staff groups 2023-06-01      RX8              Y63
# 242974                 Ambulance staff 2023-06-01      RX8              Y63
# 242975               Central functions 2023-06-01      RX8              Y63
# 242976  HCHS doctors (exc. junior Drs) 2023-06-01      RX8              Y63
# 242977       Hotel, property & estates 2023-06-01      RX8              Y63
#
#                 NHSE_REGION_NAME CLUSTER_GROUP  BENCHMARK_GROUP  \
# 242973  North East and Yorkshire     Ambulance  Ambulance Trust
# 242974  North East and Yorkshire     Ambulance  Ambulance Trust
# 242975  North East and Yorkshire     Ambulance  Ambulance Trust
# 242976  North East and Yorkshire     Ambulance  Ambulance Trust
# 242977  North East and Yorkshire     Ambulance  Ambulance Trust
#
#         FTE_DAYS_LOST  FTE_DAYS_AVAILABLE
# 242973    10350.38716        166395.39707
# 242974     2439.18285         49324.60728
# 242975      783.82827         17358.73118
# 242976            NaN                 NaN
# 242977      270.70678          6246.14884

# %%
df2.to_csv('../sickness_benchmarking.csv', index = False)
