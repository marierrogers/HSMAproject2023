# %% [markdown]
# # Explore independent and dependent variables

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
url_annual = 'annual_dash_data.csv'
#url_monthly = 'monthly_modelling_data.csv'
df_annual = pd.read_csv(url_annual,parse_dates=['month_year'],dayfirst=True)
#df_monthly = pd.read_csv(url_monthly,parse_dates=['month_year'],dayfirst=True)
# Out:
# C:\Users\MarieRogers\AppData\Local\Temp\ipykernel_1424\769072770.py:3: DtypeWarning: Columns (33) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_annual = pd.read_csv(url_annual,parse_dates=['month_year'],dayfirst=True)

# %%
corr_cols = ['leaver_rate', 'sickness_absence',
                                   'local_unemployment','joiner_rate','anxiety_stress']
correlation_matrix = df_annual[corr_cols].corr()
# Create correlation matrix heatmap using Seaborn
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Correlation Matrix')
plt.show()

# %%
sorted(df_annual['staff_group'].unique())
# Out:
# ['All staff groups',
#  'Ambulance staff',
#  'Central functions',
#  'HCHS doctors (exc. junior Drs)',
#  'Hotel, property & estates',
#  'Managers',
#  'Midwives',
#  'Nurses & health visitors',
#  'Other staff or those with unknown classification',
#  'Scientific, therapeutic & technical staff',
#  'Senior managers',
#  'Support to ST&T staff',
#  'Support to ambulance staff',
#  'Support to doctors, nurses & midwives']

# %%
staff_group = 'Nurses & health visitors'
df_sg = df_annual[df_annual['staff_group'] == staff_group].copy()

# %%
correlation_matrix = df_sg[corr_cols].corr()
# Create correlation matrix heatmap using Seaborn
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Correlation Matrix')
plt.show()

# %%
df_sg
sns.set()

plt.figure(figsize=(10, 6))  
sns.lineplot(data=df_sg, x='month_year', y='leaver_rate', hue='staff_group')
plt.xlabel('Date')
plt.ylabel('Rate')
plt.title('Rate over Time by Staff Group')
plt.legend(title='Staff Group', loc='best')  
plt.xticks(rotation=45)  
plt.show()

# %%
df_annual.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 191090 entries, 0 to 191089
# Data columns (total 50 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   org_code                 191090 non-null  object
#  1   region_name              191090 non-null  object
#  2   staff_group              191090 non-null  object
#  3   month_year               191090 non-null  datetime64[ns]
#  4   join_HC                  191090 non-null  float64
#  5   join_FTE                 191090 non-null  float64
#  6   leave_HC                 191090 non-null  float64
#  7   leave_FTE                191090 non-null  float64
#  8   denom_HC                 191090 non-null  float64
#  9   denom_FTE                191090 non-null  float64
#  10  start_date               191090 non-null  object
#  11  denom_FTE_start          191090 non-null  float64
#  12  denom_HC_start           191090 non-null  float64
#  13  denom_FTE_average        191090 non-null  float64
#  14  denom_HC_average         191090 non-null  float64
#  15  leaver_rate              191090 non-null  float64
#  16  joiner_rate              191090 non-null  float64
#  17  local_unemployment       191090 non-null  float64
#  18  sickness_absence         191090 non-null  float64
#  19  annual_sickness_absence  191090 non-null  float64
#  20  anxiety_stress           191090 non-null  float64
#  21  back_problems            191090 non-null  float64
#  22  gastro                   191090 non-null  float64
#  23  gynaecological           191090 non-null  float64
#  24  headache_mig             191090 non-null  float64
#  25  infectious_dis           191090 non-null  float64
#  26  other                    191090 non-null  float64
#  27  other_msk                191090 non-null  float64
#  28  pregnancy_related        191090 non-null  float64
#  29  respiratory              191090 non-null  float64
#  30  unknown                  191090 non-null  float64
#  31  vacancy_sg_x             191090 non-null  object
#  32  vacancy_FTE              191090 non-null  float64
#  33  vacancy_sg_y             191090 non-null  object
#  34  advertised_FTE           191090 non-null  float64
#  35  %_death_in_service       191090 non-null  float64
#  36  %_dismissal              191090 non-null  float64
#  37  %_end_of_ft              191090 non-null  float64
#  38  %_flexibility            191090 non-null  float64
#  39  %_health                 191090 non-null  float64
#  40  %_incompat_relations     191090 non-null  float64
#  41  %_other                  191090 non-null  float64
#  42  %_pay_reward             191090 non-null  float64
#  43  %_pregnancy              191090 non-null  float64
#  44  %_progression_cpd        191090 non-null  float64
#  45  %_relocation             191090 non-null  float64
#  46  %_retirement             191090 non-null  float64
#  47  %_unknown                191090 non-null  float64
#  48  %_work_life_balance      191090 non-null  float64
#  49  %_workforce_transform    191090 non-null  float64
# dtypes: datetime64[ns](1), float64(43), object(6)
# memory usage: 72.9+ MB

# %%
import matplotlib.pyplot as plt

# Assuming your DataFrame is called df
# You can specify the columns you want to include in the scatterplot matrix
cols = ['leaver_rate', 'joiner_rate', 'sickness_absence']

# Use the pairplot function to create the scatterplot matrix
sns.set(style="ticks")
sns.pairplot(df_annual[cols])

# Add title
plt.suptitle("Scatterplot Matrix", y=1.02)

# Show the plot
plt.show()
