# %%
import requests
from bs4 import BeautifulSoup
import re
import zipfile
import csv
import pandas as pd

# %%
month = "february"
year = "2023"
url = f"https://digital.nhs.uk/data-and-information/publications/statistical/nhs-workforce-statistics/{month}-{year}"
keyword = "benchmark"

# %%
def download_zip(url,month,year):
    response = requests.get(url)
    
    if response.status_code == 200:
        filename = f"turnover-{month}-{year}.zip"
        with open(filename, "wb") as file:
            file.write(response.content)
        print(f"Downloaded: {filename}")
    else:
        print(f"Failed to download the zip file from: {url}")

# %%
def find_zip_files(url, keyword,month,year):
    response = requests.get(url)
    
    if response.status_code == 200:
        soup = BeautifulSoup(response.content, "html.parser")
        zip_links = soup.find_all("a", href=re.compile(".zip"))
        
        for link in zip_links:
            if keyword in link["href"]:
                download_url = link["href"]
                download_zip(download_url,month,year)
    else:
        print("Failed to retrieve the webpage.")

# %%
find_zip_files(url,keyword,month,year)
# Out:
# Downloaded: turnover-february-2023.zip

# %%
def unzip_and_read_csv(zip_path):
    with zipfile.ZipFile(zip_path, 'r') as zip_file:
        # Extract all files in the zip folder
        zip_file.extractall()

        # Read the CSV files inside the extracted folder
        for file_name in zip_file.namelist():
            if file_name.endswith('.csv') and 'Monthly' in file_name:
                df = pd.read_csv(file_name)
                #print(df)
                return df

    return None

# %%
zip_path = f'turnover-{month}-{year}.zip'
df = unzip_and_read_csv(zip_path)

# %%
df.head()
# Out:
#              Period     Type Org code
# 0  202112 to 202201  Leavers      RXX  \
# 1  202112 to 202201  Leavers      RJ2
# 2  202112 to 202201  Leavers      RDR
# 3  202112 to 202201  Leavers      26A
# 4  202112 to 202201  Leavers      RWX
#
#                                             Org name NHSE region code
# 0  Surrey and Borders Partnership NHS Foundation ...              Y59  \
# 1                   Lewisham and Greenwich NHS Trust              Y56
# 2              Sussex Community NHS Foundation Trust              Y59
# 3                        NHS Norfolk and Waveney CCG              Y61
# 4          Berkshire Healthcare NHS Foundation Trust              Y59
#
#   NHSE region name ICS code             ICS name
# 0       South East      QXU    Surrey Heartlands  \
# 1           London      QKK    South East London
# 2       South East      QNX               Sussex
# 3  East of England      QMM  Norfolk and Waveney
# 4       South East      QNQ              Frimley
#
#                   Cluster group                        Benchmark group
# 0                 Mental Health  Mental Health and Learning Disability  \
# 1                         Acute                          Acute - Large
# 2      Community Provider Trust               Community Provider Trust
# 3  Clinical Commissioning Group           Clinical Commissioning Group
# 4                 Mental Health  Mental Health and Learning Disability
#
#         Staff group   HC        FTE
# 0  All staff groups   46   41.09334
# 1  All staff groups  112  101.00739
# 2  All staff groups   86   67.40329
# 3  All staff groups    9    8.20000
# 4  All staff groups   73   60.87147

# %% [markdown]
# Fix the period formatting

# %%
leaver_joiner = df.loc[df['Type'].isin(['Leavers','Joiners'])].copy()

# Convert the date column to string type (if not already)
leaver_joiner['Period'] = leaver_joiner['Period'].astype(str)

# Extract the year and month components from the date column
leaver_joiner['Year'] = leaver_joiner['Period'].str[:4]
leaver_joiner['Month'] = leaver_joiner['Period'].str[4:6]

# %%
# Create a new column with the desired date format
leaver_joiner['Date'] = pd.to_datetime(leaver_joiner['Year'] + '-' + leaver_joiner['Month'] + '-01')

# Drop the intermediate columns 'Year' and 'Month' if not needed
leaver_joiner = leaver_joiner.drop(['Year', 'Month','Period'], axis=1)
leaver_joiner.head()
# Out:
#       Type Org code                                           Org name
# 0  Leavers      RXX  Surrey and Borders Partnership NHS Foundation ...  \
# 1  Leavers      RJ2                   Lewisham and Greenwich NHS Trust
# 2  Leavers      RDR              Sussex Community NHS Foundation Trust
# 3  Leavers      26A                        NHS Norfolk and Waveney CCG
# 4  Leavers      RWX          Berkshire Healthcare NHS Foundation Trust
#
#   NHSE region code NHSE region name ICS code             ICS name
# 0              Y59       South East      QXU    Surrey Heartlands  \
# 1              Y56           London      QKK    South East London
# 2              Y59       South East      QNX               Sussex
# 3              Y61  East of England      QMM  Norfolk and Waveney
# 4              Y59       South East      QNQ              Frimley
#
#                   Cluster group                        Benchmark group
# 0                 Mental Health  Mental Health and Learning Disability  \
# 1                         Acute                          Acute - Large
# 2      Community Provider Trust               Community Provider Trust
# 3  Clinical Commissioning Group           Clinical Commissioning Group
# 4                 Mental Health  Mental Health and Learning Disability
#
#         Staff group   HC        FTE       Date
# 0  All staff groups   46   41.09334 2021-12-01
# 1  All staff groups  112  101.00739 2021-12-01
# 2  All staff groups   86   67.40329 2021-12-01
# 3  All staff groups    9    8.20000 2021-12-01
# 4  All staff groups   73   60.87147 2021-12-01

# %%
denoms = df.loc[df['Type'].isin(['Denoms'])]
denoms = denoms.rename(columns={'Period':'Date'})

# %%
denoms['Date'] = pd.to_datetime(denoms['Date'],format='%d/%m/%Y')

# %%
denoms['Date'] = denoms['Date'].dt.strftime('%Y-%m-01')
denoms['Date'] = pd.to_datetime(denoms['Date'])

# %%
merged_df = pd.concat([denoms,leaver_joiner])
merged_df = merged_df.drop(['ICS code','ICS name'],axis=1)

# %%
merged_df.tail()
# Out:
#              Date     Type Org code
# 442245 2023-01-01  Leavers      RTR  \
# 442246 2023-01-01  Leavers      RCF
# 442247 2023-01-01  Leavers      RGD
# 442248 2023-01-01  Leavers      RR8
# 442249 2023-01-01  Leavers      RXF
#
#                                                Org name NHSE region code
# 442245        South Tees Hospitals NHS Foundation Trust              Y63  \
# 442246                    Airedale NHS Foundation Trust              Y63
# 442247  Leeds and York Partnership NHS Foundation Trust              Y63
# 442248               Leeds Teaching Hospitals NHS Trust              Y63
# 442249                Mid Yorkshire Hospitals NHS Trust              Y63
#
#                 NHSE region name  Cluster group
# 442245  North East and Yorkshire          Acute  \
# 442246  North East and Yorkshire          Acute
# 442247  North East and Yorkshire  Mental Health
# 442248  North East and Yorkshire          Acute
# 442249  North East and Yorkshire          Acute
#
#                               Benchmark group            Staff group  HC
# 442245                       Acute - Teaching  Support to ST&T staff   7  \
# 442246                          Acute - Small  Support to ST&T staff   2
# 442247  Mental Health and Learning Disability  Support to ST&T staff   6
# 442248                       Acute - Teaching  Support to ST&T staff  14
# 442249                          Acute - Large  Support to ST&T staff   6
#
#              FTE
# 442245   5.58333
# 442246   0.72000
# 442247   6.00000
# 442248  12.22000
# 442249   5.23333

# %%
df_p = merged_df.pivot(index=['Date','Org code','Org name','NHSE region code','NHSE region name','Cluster group',
                       'Benchmark group','Staff group'], columns='Type', values=['HC','FTE']).reset_index()

# %%
# Flatten the column multi-index

df_p.columns = [f'{col[0]}_{col[1]}' if col[1] else col[0] for col in df_p.columns]

# %%
df_p.tail()
# Out:
#              Date Org code                                       Org name
# 193665 2023-02-01      TAJ  Black Country Healthcare NHS Foundation Trust  \
# 193666 2023-02-01      TAJ  Black Country Healthcare NHS Foundation Trust
# 193667 2023-02-01      TAJ  Black Country Healthcare NHS Foundation Trust
# 193668 2023-02-01      TAJ  Black Country Healthcare NHS Foundation Trust
# 193669 2023-02-01      TAJ  Black Country Healthcare NHS Foundation Trust
#
#        NHSE region code NHSE region name  Cluster group
# 193665              Y60         Midlands  Mental Health  \
# 193666              Y60         Midlands  Mental Health
# 193667              Y60         Midlands  Mental Health
# 193668              Y60         Midlands  Mental Health
# 193669              Y60         Midlands  Mental Health
#
#                               Benchmark group
# 193665  Mental Health and Learning Disability  \
# 193666  Mental Health and Learning Disability
# 193667  Mental Health and Learning Disability
# 193668  Mental Health and Learning Disability
# 193669  Mental Health and Learning Disability
#
#                                       Staff group  HC_Denoms  HC_Joiners
# 193665                   Nurses & health visitors     1102.0         NaN  \
# 193666  Scientific, therapeutic & technical staff      494.0         NaN
# 193667                            Senior managers       56.0         NaN
# 193668                      Support to ST&T staff      437.0         NaN
# 193669      Support to doctors, nurses & midwives      999.0         NaN
#
#         HC_Leavers  FTE_Denoms  FTE_Joiners  FTE_Leavers
# 193665         NaN  1007.47300          NaN          NaN
# 193666         NaN   429.24553          NaN          NaN
# 193667         NaN    55.60000          NaN          NaN
# 193668         NaN   402.21200          NaN          NaN
# 193669         NaN   871.02637          NaN          NaN

# %% [markdown]
# SIP data to month later than leaver data in monthly turnover! Remove final month of data in merged DF

# %%
# Find the maximum date value in the 'Date' column
#max_date = merged_df['Date'].max()

# Remove data with the latest date value
#merged_df = merged_df[merged_df['Date'] < max_date]

# %%
df_p.to_csv(f'../02_data/turnover-processed-{month}-{year}.csv', index=False)
